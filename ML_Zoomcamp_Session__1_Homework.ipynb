# %% [markdown]
# <a href="https://colab.research.google.com/github/subair99/ML_Zoomcamp_2022/blob/main/ML_Zoomcamp_Session__1_Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/MyDrive/Colab Notebooks/ML_Zoomcamp_2022/Week_01

# %%
# !wget https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-02-car-price/data.csv

# %% [markdown]
# ### Question 1
# What's the version of NumPy that you installed?
#
# You can get the version information using the __version__ field:

# %%
np.__version__
# Out:
# '1.21.6'

# %% [markdown]
# Answer: 1.21.6

# %% [markdown]
# ### Question 2
# How many records are in the dataset?
#
# Here you need to specify the number of rows.
#
# 1. 16
# 2. 6572
# 3. 11914
# 4. 18990

# %%
cars = pd.read_csv('data.csv')

# %%
cars.shape
# Out:
# (11914, 16)

# %% [markdown]
# Answer: 11914

# %% [markdown]
# ### Question 3
# Who are the most frequent car manufacturers (top-3) according to the dataset?
#
# 1. Chevrolet, Volkswagen, Toyota
# 2. Chevrolet, Ford, Toyota
# 3. Ford, Volkswagen, Toyota
# 4. Chevrolet, Ford, Volkswagen

# %%
cars['Make'].value_counts()
# Out:
# Chevrolet        1123
# Ford              881
# Volkswagen        809
# Toyota            746
# Dodge             626
# Nissan            558
# GMC               515
# Honda             449
# Mazda             423
# Cadillac          397
# Mercedes-Benz     353
# Suzuki            351
# BMW               334
# Infiniti          330
# Audi              328
# Hyundai           303
# Volvo             281
# Subaru            256
# Acura             252
# Kia               231
# Mitsubishi        213
# Lexus             202
# Buick             196
# Chrysler          187
# Pontiac           186
# Lincoln           164
# Oldsmobile        150
# Land Rover        143
# Porsche           136
# Saab              111
# Aston Martin       93
# Plymouth           82
# Bentley            74
# Ferrari            69
# FIAT               62
# Scion              60
# Maserati           58
# Lamborghini        52
# Rolls-Royce        31
# Lotus              29
# Tesla              18
# ...

# %% [markdown]
# Answer: Chevrolet, Volkswagen

# %% [markdown]
# ### Question 4
#
# What's the number of unique Audi car models in the dataset?
# 1. 3
# 2. 16
# 3. 26
# 4. 34

# %%
cars[cars['Make'] == 'Audi']['Model'].nunique()
# Out:
# 34

# %% [markdown]
# Answer: 34

# %% [markdown]
# ### Question 5
# How many columns in the dataset have missing values?
#
# 1. 5
# 2. 6
# 3. 7
# 4. 8

# %%
cars.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %% [markdown]
# ### Question 6
# 1. Find the median value of "Engine Cylinders" column in the dataset.
# 2. Next, calculate the most frequent value of the same "Engine Cylinders".
# 3. Use the fillna method to fill the missing values in "Engine Cylinders" with the most frequent value from the previous step.
# 4. Now, calculate the median value of "Engine Cylinders" once again.
#
# Has it changed?
#
# Hint: refer to existing mode and median functions to complete the task.
#
# 1. Yes
# 2. No

# %%
cars['Engine Cylinders'].median()
# Out:
# 6.0

# %%
cars['Engine Cylinders'].mode()
# Out:
# 0    4.0
# dtype: float64

# %%
value = {'Engine Cylinders': 4}
cars.fillna(value=value, inplace=True)

# %%
cars.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders        0
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
cars['Engine Cylinders'].median()
# Out:
# 6.0

# %% [markdown]
# Answer: No

# %% [markdown]
# ### Question 7
# 1. Select all the "Lotus" cars from the dataset.
# 2. Select only columns "Engine HP", "Engine Cylinders".
# 3. Now drop all duplicated rows using drop_duplicates method (you should get a dataframe with 9 rows).
# 4. Get the underlying NumPy array. Let's call it X.
# 5. Compute matrix-matrix multiplication between the transpose of X and X. To get the transpose, use X.T. Let's call the result XTX.
# 6. Invert XTX.
# 7. Create an array y with values [1100, 800, 750, 850, 1300, 1000, 1000, 1300, 800].
# 8. Multiply the inverse of XTX with the transpose of X, and then multiply the result by y. Call the result w.
# 9. What's the value of the first element of w?
#
# Note: You just implemented linear regression. We'll talk about it in the next lesson.
#
# 1. -0.0723
# 2. 4.5949
# 3. 31.6537
# 4. 63.5643

# %%
cars[cars['Make'] == 'Lotus']
# Out:
#        Make      Model  Year                Engine Fuel Type  Engine HP  \
# 3912  Lotus      Elise  2009     premium unleaded (required)      189.0
# 3913  Lotus      Elise  2009     premium unleaded (required)      218.0
# 3914  Lotus      Elise  2009     premium unleaded (required)      189.0
# 3915  Lotus      Elise  2010     premium unleaded (required)      189.0
# 3916  Lotus      Elise  2010     premium unleaded (required)      218.0
# 3917  Lotus      Elise  2011     premium unleaded (required)      189.0
# 3918  Lotus      Elise  2011     premium unleaded (required)      217.0
# 3919  Lotus      Elise  2011     premium unleaded (required)      217.0
# 4216  Lotus     Esprit  2002     premium unleaded (required)      350.0
# 4217  Lotus     Esprit  2003     premium unleaded (required)      350.0
# 4218  Lotus     Esprit  2004     premium unleaded (required)      350.0
# 4257  Lotus  Evora 400  2017     premium unleaded (required)      400.0
# ...

# %%
cars[cars['Make'] == 'Lotus'][["Engine HP", "Engine Cylinders"]]
# Out:
#       Engine HP  Engine Cylinders
# 3912      189.0               4.0
# 3913      218.0               4.0
# 3914      189.0               4.0
# 3915      189.0               4.0
# 3916      218.0               4.0
# 3917      189.0               4.0
# 3918      217.0               4.0
# 3919      217.0               4.0
# 4216      350.0               8.0
# 4217      350.0               8.0
# 4218      350.0               8.0
# 4257      400.0               6.0
# 4258      400.0               6.0
# 4259      276.0               6.0
# 4260      276.0               6.0
# 4261      276.0               6.0
# 4262      345.0               6.0
# 4263      345.0               6.0
# 4264      276.0               6.0
# 4265      345.0               6.0
# 4266      276.0               6.0
# 4267      345.0               6.0
# 4268      276.0               6.0
# 4292      257.0               4.0
# 4293      240.0               4.0
# 4294      240.0               4.0
# ...

# %%
X = cars[cars['Make'] == 'Lotus'][["Engine HP", "Engine Cylinders"]].drop_duplicates()
X
# Out:
#       Engine HP  Engine Cylinders
# 3912      189.0               4.0
# 3913      218.0               4.0
# 3918      217.0               4.0
# 4216      350.0               8.0
# 4257      400.0               6.0
# 4259      276.0               6.0
# 4262      345.0               6.0
# 4292      257.0               4.0
# 4293      240.0               4.0

# %%
TX = X.T
TX
# Out:
#                    3912   3913   3918   4216   4257   4259   4262   4292  \
# Engine HP         189.0  218.0  217.0  350.0  400.0  276.0  345.0  257.0
# Engine Cylinders    4.0    4.0    4.0    8.0    6.0    6.0    6.0    4.0
#
#                    4293
# Engine HP         240.0
# Engine Cylinders    4.0

# %%
XTX = TX.dot(X)
XTX
# Out:
#                   Engine HP  Engine Cylinders
# Engine HP          731684.0           13410.0
# Engine Cylinders    13410.0             252.0

# %%
inXTX = np.linalg.inv(XTX)
inXTX
# Out:
# array([[ 5.53084235e-05, -2.94319825e-03],
#        [-2.94319825e-03,  1.60588447e-01]])

# %%
y = [1100, 800, 750, 850, 1300, 1000, 1000, 1300, 800]
y
# Out:
# [1100, 800, 750, 850, 1300, 1000, 1000, 1300, 800]

# %%
intra = inXTX.dot(TX)
intra
# Out:
# array([[-1.31950096e-03,  2.84443321e-04,  2.29134897e-04,
#         -4.18763778e-03,  4.46417989e-03, -2.39406462e-03,
#          1.42221660e-03,  2.44147184e-03,  1.50122864e-03],
#        [ 8.60893170e-02,  7.36567735e-04,  3.67976598e-03,
#          2.54588185e-01, -2.13748621e-01,  1.51207962e-01,
#         -5.18727169e-02, -1.14048164e-01, -6.40137937e-02]])

# %%
w = intra.dot(y)
w
# Out:
# array([  4.59494481, -63.56432501])

# %% [markdown]
# Answer: 4.5949
